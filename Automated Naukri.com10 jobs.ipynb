# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import selenium
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome(r"C:\chromedriver.exe")
driver.get('https://www.naukri.com/')
driver.find_element_by_id('qsb-keyword-sugg').send_keys('Data Analyst')
driver.find_element_by_xpath("//input[@id='qsb-location-sugg']").send_keys('Bangalore')
driver.find_element_by_xpath("//div[@class='search-btn']/button").click()

# %%
job_names=[]
company=[]
location=[]
experience=[]
salary=[]
for i in list(driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"))[:10]:
    job_names.append(i.text)
for i in list(driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']"))[:10]:  
    company.append(i.text)
for i in list(driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']"))[:10]:
    location.append(i.text)
for i in list(driver.find_elements_by_xpath("//span[@class='ellipsis fleft fs12 lh16']"))[:30]:
    experience.append(i.text)
job_df=pd.DataFrame({'Job_Names':job_names,
                         'Company':company,
                         'location':location,
                         'Experience':experience[0::3],
                         'Salary':experience[1::3]})
job_df.to_csv('Data Scientist Naukri.com', index = False)
print(job_df)
# Out:
#                                            Job_Names  \
# 0  Fresher Data Engineer / Data Scientist / Data ...
# 1                        Data Scientist/Data Analyst
# 2                              Business Data Analyst
# 3  SAS AML Data Analyst / Trainee & Data Science,...
# 4                               Hiring Data Analysts
# 5                               Hiring Data Analysts
# 6                                       Data Analyst
# 7                                 Study Data Analyst
# 8                                       Data Analyst
# 9         Business Data Analyst | Reinsurance Domain
#
#                                              Company  \
# 0                      ACHYUTAS SOFT PRIVATE LIMITED
# 1  CAIA-Center For Artificial Intelligence & Adva...
# 2                                             NetApp
# 3                         MagicBase Royal BD Pvt Ltd
# 4                  Flipkart Internet Private Limited
# 5                  Flipkart Internet Private Limited
# ...

# %%
job_df
# Out:
#                                            Job_Names  \
# 0  Fresher Data Engineer / Data Scientist / Data ...
# 1                        Data Scientist/Data Analyst
# 2                              Business Data Analyst
# 3  SAS AML Data Analyst / Trainee & Data Science,...
# 4                               Hiring Data Analysts
# 5                               Hiring Data Analysts
# 6                                       Data Analyst
# 7                                 Study Data Analyst
# 8                                       Data Analyst
# 9         Business Data Analyst | Reinsurance Domain
#
#                                              Company  \
# 0                      ACHYUTAS SOFT PRIVATE LIMITED
# 1  CAIA-Center For Artificial Intelligence & Adva...
# 2                                             NetApp
# 3                         MagicBase Royal BD Pvt Ltd
# 4                  Flipkart Internet Private Limited
# 5                  Flipkart Internet Private Limited
# ...
