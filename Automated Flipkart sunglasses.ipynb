# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import selenium
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome(r"C:\chromedriver.exe")
driver.get('https://www.flipkart.com/')
driver.find_element_by_xpath("//input[@class='_3704LK']").send_keys('Sunglasses')
driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']").click()
driver.find_element_by_xpath("//button[@class='L0Z3Pu']").click()
time.sleep(5)

# %%
brand_names=[]
price=[]
discount=[]
desc=[]
for i in list(driver.find_elements_by_xpath("//div[@class='_2WkVRV']")):
    brand_names.append(i.text)
for i in list(driver.find_elements_by_xpath("//div[@class='_30jeq3']")):  
    price.append(i.text)
for i in list(driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")):
    discount.append(i.text)
for i in list(driver.find_elements_by_xpath("//div[@class='_2B099V']/a")):
    desc.append(i.text)
li=[]
link = driver.find_elements_by_xpath("//a[@class='ge-49M']")
for i in link:
    li.append(i.get_attribute('href'))   
for i in li[:3]:
    driver.get(i)
    time.sleep(5)
    for i in list(driver.find_elements_by_xpath("//div[@class='_2WkVRV']")):
        brand_names.append(i.text)
    for i in list(driver.find_elements_by_xpath("//div[@class='_30jeq3']")):
        price.append(i.text)
    for i in list(driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")):
        discount.append(i.text)
    for i in list(driver.find_elements_by_xpath("//div[@class='_2B099V']/a")):
        desc.append(i.text)    

    

job_df=pd.DataFrame({'Brand':brand_names[:100],
                         'Price':price[:100],
                         'Discount':discount[:100],
                         'Description':desc[0::2][:100]})
job_df.to_csv('Sunglasses of flipkart', index = False)
print(job_df)
# Out:
#              Brand Price Discount  \
# 0        Royal Son  ₹699  65% off
# 1             hipe  ₹185  86% off
# 2   FDA COLLECTION  ₹210  83% off
# 3   FDA COLLECTION  ₹210  85% off
# 4       Phenomenal  ₹399  80% off
# ..             ...   ...      ...
# 95  kingsunglasses  ₹219  81% off
# 96      Phenomenal  ₹399  80% off
# 97        DAHAAZIL  ₹149  70% off
# 98        Fastrack  ₹662  26% off
# 99       Royal Son  ₹399  73% off
#
#                                           Description
# 0          UV Protection Retro Square Sunglasses (49)
# 1   UV Protection, Mirrored, Night Vision, Gradien...
# 2   Gradient, Mirrored, UV Protection Round, Round...
# 3   Gradient, Mirrored, UV Protection Round, Round...
# 4   UV Protection, Mirrored Retro Square Sunglasse...
# ..                                                ...
# 95      UV Protection, Mirrored Round Sunglasses (54)
# 96  UV Protection Retro Square Sunglasses (Free Size)
# 97                     Gradient Round Sunglasses (55)
# 98       UV Protection Aviator Sunglasses (Free Size)
# 99                   Mirrored Aviator Sunglasses (55)
#
# [100 rows x 4 columns]

# %%
job_df
# Out:
#              Brand Price Discount  \
# 0        Royal Son  ₹699  65% off
# 1             hipe  ₹185  86% off
# 2   FDA COLLECTION  ₹210  83% off
# 3   FDA COLLECTION  ₹210  85% off
# 4       Phenomenal  ₹399  80% off
# ..             ...   ...      ...
# 95  kingsunglasses  ₹219  81% off
# 96      Phenomenal  ₹399  80% off
# 97        DAHAAZIL  ₹149  70% off
# 98        Fastrack  ₹662  26% off
# 99       Royal Son  ₹399  73% off
#
#                                           Description
# 0          UV Protection Retro Square Sunglasses (49)
# 1   UV Protection, Mirrored, Night Vision, Gradien...
# 2   Gradient, Mirrored, UV Protection Round, Round...
# 3   Gradient, Mirrored, UV Protection Round, Round...
# 4   UV Protection, Mirrored Retro Square Sunglasse...
# ..                                                ...
# 95      UV Protection, Mirrored Round Sunglasses (54)
# 96  UV Protection Retro Square Sunglasses (Free Size)
# 97                     Gradient Round Sunglasses (55)
# 98       UV Protection Aviator Sunglasses (Free Size)
# 99                   Mirrored Aviator Sunglasses (55)
#
# [100 rows x 4 columns]
