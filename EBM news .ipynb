# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import selenium
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome(r"C:\chromedriver.exe")

# %%
date =[]
vertical=[]
author=[]
headline=[]
vertical_page=[]
description=[]
for i in range(162,260):
    driver.get("https://www.ebmnews.com/2018/page/%d" %i)
    for i in list(driver.find_elements_by_xpath("//h2[@class='title']")):
        headline.append(i.text)
    for i in list(driver.find_elements_by_xpath("//span[@class='time']")):
        date.append(i.text)
    for i in list(driver.find_elements_by_xpath("//i[@class='post-author author']")):
        author.append(i.text)
    for i in list(driver.find_elements_by_xpath("//div[@class='post-summary']")):
        description.append(i.text)
    for i in list(driver.find_elements_by_xpath("//h2[@class='title']/a")):
        vertical_page.append(i.get_attribute('href'))

# %%
for i in vertical_page:
        driver.get(i)
        for i in list(driver.find_elements_by_xpath("//div[@class='post-meta-wrap clearfix']/div")):
            vertical.append(i.text)

            
news_df=pd.DataFrame({'Vertical':vertical,
                         'Headline':headline,
                         'Date':date,
                         'Description':description,
                         'Author':author})
news_df.to_csv('EBM news', index = False)
print(news_df)
# Out:
#                   Vertical                                           Headline  \
# 0                   SPORTS  Sri Lanka legend snubs desperate cricket selec...
# 1           FOOTBALLSPORTS  Victor Wanyama, a Kenyan footballer who plays ...
# 2           FOOTBALLSPORTS  Kenya urged to set up football academies to nu...
# 3           FOOTBALLSPORTS  Saudi footballers to be penalised for rout by ...
# 4            FEATUREDWORLD  New York State Sues Donald Trump and His Non-P...
# ..                     ...                                                ...
# 975     CRIMEDELHINATIONAL  Ministry of Defence website hacked by suspecte...
# 976  CRIMEFEATUREDNATIONAL  Goa on alert after intel on terrorists using s...
# 977  DELHIFEATUREDNATIONAL  Congress fumes after Amit Shah compares opposi...
# 978  BUSINESSDELHIFEATURED  Centre opens contest for more than 100 fighter...
# 979  BUSINESSDELHIFEATURED  Has your data been leaked? Facebook to send no...
#
# ...

# %%
news_df
# Out:
#                   Vertical                                           Headline  \
# 0                   SPORTS  Sri Lanka legend snubs desperate cricket selec...
# 1           FOOTBALLSPORTS  Victor Wanyama, a Kenyan footballer who plays ...
# 2           FOOTBALLSPORTS  Kenya urged to set up football academies to nu...
# 3           FOOTBALLSPORTS  Saudi footballers to be penalised for rout by ...
# 4            FEATUREDWORLD  New York State Sues Donald Trump and His Non-P...
# ..                     ...                                                ...
# 975     CRIMEDELHINATIONAL  Ministry of Defence website hacked by suspecte...
# 976  CRIMEFEATUREDNATIONAL  Goa on alert after intel on terrorists using s...
# 977  DELHIFEATUREDNATIONAL  Congress fumes after Amit Shah compares opposi...
# 978  BUSINESSDELHIFEATURED  Centre opens contest for more than 100 fighter...
# 979  BUSINESSDELHIFEATURED  Has your data been leaked? Facebook to send no...
#
# ...
